# %% [markdown]
# <a href="https://colab.research.google.com/github/TheTechArtist-Varni/social__sentiment/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Analyzing weather data using a CSV file and basic Pandas commands**

# %% [markdown]
# Importing pandas in order to use in built functions

# %%
import pandas as pd

# %% [markdown]
# Reading the
#  csv file

# %%
data= pd.read_csv("/content/weatherHistory.csv")

# %% [markdown]
# Partially viewing the dataset

# %%
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# **How to analyze data frames**

# %% [markdown]
# Viewing the first 'n' rows of dataset here n = 5

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# Viewing the number of rows and columns in the dataset

# %%
data.shape
# Out:
# (96453, 12)

# %% [markdown]
# Viewing the Range of the dataset

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %% [markdown]
# Viewing dataset column names

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %% [markdown]
# Viewing the datatypes of each column

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %% [markdown]
# Viewing number of non null data in each column

# %%
 data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Weather                     96453
# dtype: int64

# %% [markdown]
# Finding out the unique values in Summary column

# %%
data['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %% [markdown]
#  The number of unique  values in each column

# %%
 data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %% [markdown]
# Basic information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# # QUESTIONS AND ANSWERS
# 1. Find all unique "windspeed" values

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %% [markdown]
# 2. Find number of times 9.9820
# is the visibility

# %%
filtered_data = data[data['Visibility (km)'] == '9.9820']

# %% [markdown]
# 3.Find the no of timed windspeed was 4km/h

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
data[data['Wind Speed (km/h)']=='4']
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.rename(columns={'Daily Summary':'Weather'},inplace=True)

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# 4. What is the mean Humidity?

# %%
data.Humidity.mean()
# Out:
# np.float64(0.7348989663359355)

# %% [markdown]
# 5. What is the standarad deviation of Humidity

# %%
data.Humidity.std()
# Out:
# 0.19547273906722662

# %% [markdown]
# 6. Find  the variance of summary

# %%
data['Humidity'].dtype
# Out:
# dtype('float64')

# %%
data['Humidity'].var()
# Out:
# 0.03820959171844407

# %% [markdown]
# 7. Find all instances when rain was recorded

# %%
data[data['Precip Type']=='rain']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# 8. Find all the instances where wind speed>24 and visibility>25

# %%
(data['Wind Speed (km/h)']>24)&(data['Visibility (km)']>25)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 96448    False
# 96449    False
# 96450    False
# 96451    False
# 96452    False
# Length: 96453, dtype: bool

# %% [markdown]
# 9. Find the mean value of each column against Weather

# %%
data.groupby('Humidity').mean(numeric_only=True)
# Out:
#           Temperature (C)  Apparent Temperature (C)  Wind Speed (km/h)  \
# Humidity
# 0.00           -13.560606                -17.626263           9.568523
# 0.12            13.888889                 13.888889          28.980000
# 0.13            39.905556                 37.538889          23.586500
# 0.14            32.637500                 30.873611          15.415750
# 0.15            25.514444                 23.225000          18.880470
# ...                   ...                       ...                ...
# 0.96             5.595618                  4.289998           7.590989
# 0.97            13.613889                 13.124532           6.666064
# 0.98             5.327339                  3.922749           7.739709
# 0.99             4.650046                  3.248368           7.588719
# 1.00             4.502276                  3.049792           7.586292
#
#           Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# Humidity
# ...

# %% [markdown]
# 10. Find min and max values of each column against Humidity

# %%
data.groupby('Humidity')['Temperature (C)'].max()
# Out:
# Humidity
# 0.00     1.111111
# 0.12    13.888889
# 0.13    39.905556
# 0.14    38.983333
# 0.15    39.588889
#           ...
# 0.96    22.688889
# 0.97    21.583333
# 0.98    22.138889
# 0.99    22.088889
# 1.00    21.555556
# Name: Temperature (C), Length: 90, dtype: float64

# %%
data.groupby('Humidity')['Temperature (C)'].min()
# Out:
# Humidity
# 0.00   -17.777778
# 0.12    13.888889
# 0.13    39.905556
# 0.14    15.000000
# 0.15     1.133333
#           ...
# 0.96   -13.194444
# 0.97    -5.988889
# 0.98    -9.161111
# 0.99   -14.005556
# 1.00    -8.888889
# Name: Temperature (C), Length: 90, dtype: float64

# %% [markdown]
# 11. Show all records when weather is 'Partly cloudy throughout the day.'

# %%
data[data['Weather']== 'Partly cloudy throughout the day.']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96400  2016-09-07 19:00:00.000 +0200  Partly Cloudy        rain
# 96401  2016-09-07 20:00:00.000 +0200  Partly Cloudy        rain
# 96402  2016-09-07 21:00:00.000 +0200  Partly Cloudy        rain
# 96403  2016-09-07 22:00:00.000 +0200  Partly Cloudy        rain
# 96404  2016-09-07 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# 12. Find all instances when 'weather' is 'Partly cloudy throughout the day.'or visibility>40

# %%
data[
    (data['Weather'] == 'Partly cloudy throughout the day.') |
    (data['Visibility (km)'] > 40)
]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96400  2016-09-07 19:00:00.000 +0200  Partly Cloudy        rain
# 96401  2016-09-07 20:00:00.000 +0200  Partly Cloudy        rain
# 96402  2016-09-07 21:00:00.000 +0200  Partly Cloudy        rain
# 96403  2016-09-07 22:00:00.000 +0200  Partly Cloudy        rain
# 96404  2016-09-07 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...
